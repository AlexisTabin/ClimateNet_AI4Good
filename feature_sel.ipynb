# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from netCDF4 import Dataset
from itertools import combinations
from scipy.stats import f_oneway, kendalltau, pearsonr, spearmanr

# %%
from os import listdir, path
from os.path import join, isfile
from tqdm import tqdm
import xarray as xr
from datetime import datetime
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_classif
import numpy as np

# %%
train_path = [r"C:/Users/amali/Desktop/AI4Good Local folder/data/raw/train/"+f for f in listdir('C:/Users/amali/Desktop/AI4Good Local folder/data/raw/train') if isfile(join('C:/Users/amali/Desktop/AI4Good Local folder/data/raw/train', f))]
# test_path = [r"C:/Users/amali/Desktop/ETH/AI4Good/ClimateNet-main/ClimateNet-main/data/test/"+f for f in listdir('C:/Users/amali/Desktop/ETH/AI4Good/ClimateNet-main/ClimateNet-main/data/test') if isfile(join('C:/Users/amali/Desktop/ETH/AI4Good/ClimateNet-main/ClimateNet-main/data/test', f))]

train = [xr.load_dataset(file_path) for file_path in tqdm(train_path)]
# test = [xr.load_dataset(file_path) for file_path in tqdm(test_path)]

# %%
train[0]
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 768, lon: 1152, time: 1)
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.77 -89.53 -89.3 ... 89.3 89.53 89.77 90.0
#   * lon      (lon) float64 0.0 0.3125 0.625 0.9375 ... 358.8 359.1 359.4 359.7
#   * time     (time) object 'data-1996-06-09-01-1.nc'
# Data variables: (12/17)
#     TMQ      (time, lat, lon) float32 0.4082 0.4082 0.4082 ... 8.5 8.5 8.5
#     U850     (time, lat, lon) float32 -4.827 -4.79 -4.753 ... -5.806 -5.806
#     V850     (time, lat, lon) float32 -6.76 -6.787 -6.813 ... 0.09282 0.1245
#     UBOT     (time, lat, lon) float32 -4.827 -4.79 -4.753 ... -3.935 -3.942
#     VBOT     (time, lat, lon) float32 -6.76 -6.787 -6.813 ... -1.293 -1.271
#     QREFHT   (time, lat, lon) float32 4.575e-05 4.575e-05 ... 0.002404 0.002404
#     ...       ...
#     TS       (time, lat, lon) float32 222.0 222.0 222.0 ... 269.6 269.6 269.6
#     TREFHT   (time, lat, lon) float32 225.0 225.0 225.0 ... 268.5 268.5 268.5
# ...

# %%
feature_names = ['TMQ', 'U850', 'V850', 'UBOT', 'VBOT', 'QREFHT', 'PS', 'PSL', 'T200', 'T500', 'PRECT', 'TS', 'TREFHT', 'Z1000', 'Z200', 'ZBOT']
np.array(train[0]['TMQ']).reshape(-1)
# Out:
# (884736,)
